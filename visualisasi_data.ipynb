# %%
# 1️⃣ Import Library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 2️⃣ Load Data
df = pd.read_excel('data/Data_Mahasiswa_Nama_NIM_Fix.xlsx')
df.head()
# Out:
#         NIM           Nama Mahasiswa             Jurusan   IPK  Jumlah SKS  \
# 0  22821778       Cawisono Padmasari  Teknik Informatika  2.93         127
# 1  22945421           Jinawi Maulana    Sistem Informasi  3.73         138
# 2  22328207   Putri Zulaika, S.I.Kom    Sistem Informasi  2.81         137
# 3  22662562  Tgk. Mariadi Widiastuti           Akuntansi  2.00         121
# 4  22755041           Hendri Pratama           Akuntansi  2.53         106
#
#    Nilai Mata Kuliah  Jumlah Kehadiran  Jumlah Tugas Status (Lulus/Tidak)  \
# 0              83.42                13             7                Lulus
# 1              61.00                10             7                Lulus
# 2              96.28                12             7                Lulus
# 3              85.06                14             7          Tidak Lulus
# 4              88.65                15             5                Lulus
#
#    Skor Penilaian Dosen  Waktu Penyelesaian       CPL      CPMK
# ...

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Status (Lulus/Tidak)', data=df)
plt.title('Distribusi Kelas Target')
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi Antar Fitur')
plt.show()

# %%
df.hist(bins=20, figsize=(15, 10))
plt.suptitle('Distribusi Tiap Fitur', fontsize=16)
plt.show()

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Misal data kamu
df = df.drop(['Nama Mahasiswa'])
X = df.drop('Status (Lulus/Tidak)', axis=1)
y = df['Status (Lulus/Tidak)']

# Bagi data dulu sebelum oversampling
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# Terapkan SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       2 from sklearn.model_selection import train_test_split
#       4 # Misal data kamu
# ----> 5 df = df.drop(['Nama Mahasiswa'])
#       6 X = df.drop('Status (Lulus/Tidak)', axis=1)
#       7 y = df['Status (Lulus/Tidak)']
#
# File c:\Users\MyBook SAGA 10\Documents\git\Aplikasi_Kinerja_Mahasiswa\.venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
# ...
